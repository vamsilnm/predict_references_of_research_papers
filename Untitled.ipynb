# %%
import pandas as pd

# %%
information_train = pd.read_csv('train/information_train.csv',delimiter='\t')
train = pd.read_csv('train/train.csv',delimiter='\t')

# %%
information_train.head()
# Out:
#                                             abstract  \
# 0  Among bioethicists and members of the public, ...
# 1  Genomics resources that use samples from ident...
# 2  Alleviating health disparities in the United S...
# 3  Protecting the confidentiality of genetic rese...
# 4  Whereas the human linkage map appears on limit...
#
#                                        article_title  \
# 0  The routinisation of genomics and genetics: im...
# 1  Integrating ethics and science in the Internat...
# 2            Genetic Research and Health Disparities
# 3  Certificates of confidentiality: a valuable to...
# 4        Linkage disequilibrium in human populations
#
#                                           author_str      pmid    pub_date  \
# 0                 M W Foster, C D M Royal, R R Sharp  17074820  2006-11-01
# 1                                                NaN  15153999  2008-02-25
# 2  Pamela Sankar, Mildred K. Cho, Celeste M. Cond...  15213210  2008-02-20
# ...

# %%
information_train.columns.values
# Out:
# array(['abstract', 'article_title', 'author_str', 'pmid', 'pub_date',
#        'set', 'full_Text'], dtype=object)

# %%
df_sample
# Out:
#                                             abstract  \
# 0  Among bioethicists and members of the public, ...
# 1  Among bioethicists and members of the public, ...
# 2  Among bioethicists and members of the public, ...
# 3  Among bioethicists and members of the public, ...
# 4  Among bioethicists and members of the public, ...
# 5  Among bioethicists and members of the public, ...
#
#                                        article_title  \
# 0  The routinisation of genomics and genetics: im...
# 1  The routinisation of genomics and genetics: im...
# 2  The routinisation of genomics and genetics: im...
# 3  The routinisation of genomics and genetics: im...
# 4  The routinisation of genomics and genetics: im...
# 5  The routinisation of genomics and genetics: im...
#
#                            author_str      pmid    pub_date set full_Text
# 0  M W Foster, C D M Royal, R R Sharp  17074820  2006-11-01  13       NaN
# ...

# %%
df_sample = pd.DataFrame(information_train.iloc[1]).transpose()
df_sample = df_sample.append([df_sample]*4,ignore_index=True)
df_sample_2 = information_train.iloc[2:7]

df_sample.reset_index(drop=True, inplace=True)
df_sample_2.reset_index(drop=True, inplace=True)
 
result_1 = pd.concat([df_sample, df_sample_2], axis=1)
result_1
# Out:
#                                             abstract  \
# 0  Genomics resources that use samples from ident...
# 1  Genomics resources that use samples from ident...
# 2  Genomics resources that use samples from ident...
# 3  Genomics resources that use samples from ident...
# 4  Genomics resources that use samples from ident...
#
#                                        article_title author_str      pmid  \
# 0  Integrating ethics and science in the Internat...        NaN  15153999
# 1  Integrating ethics and science in the Internat...        NaN  15153999
# 2  Integrating ethics and science in the Internat...        NaN  15153999
# 3  Integrating ethics and science in the Internat...        NaN  15153999
# 4  Integrating ethics and science in the Internat...        NaN  15153999
#
#      pub_date  set full_Text  \
# 0  2008-02-25   13       NaN
# 1  2008-02-25   13       NaN
# 2  2008-02-25   13       NaN
# 3  2008-02-25   13       NaN
# 4  2008-02-25   13       NaN
#
# ...

# %%
df_sample = pd.DataFrame(information_train.iloc[0]).transpose()
df_sample = df_sample.append([df_sample]*4,ignore_index=True)
df_sample_2 = information_train.iloc[1:6]

df_sample.reset_index(drop=True, inplace=True)
df_sample_2.reset_index(drop=True, inplace=True)
 
result = pd.concat([df_sample, df_sample_2], axis=1)
result
# Out:
#                                             abstract  \
# 0  Among bioethicists and members of the public, ...
# 1  Among bioethicists and members of the public, ...
# 2  Among bioethicists and members of the public, ...
# 3  Among bioethicists and members of the public, ...
# 4  Among bioethicists and members of the public, ...
#
#                                        article_title  \
# 0  The routinisation of genomics and genetics: im...
# 1  The routinisation of genomics and genetics: im...
# 2  The routinisation of genomics and genetics: im...
# 3  The routinisation of genomics and genetics: im...
# 4  The routinisation of genomics and genetics: im...
#
#                            author_str      pmid    pub_date  set full_Text  \
# 0  M W Foster, C D M Royal, R R Sharp  17074820  2006-11-01   13       NaN
# 1  M W Foster, C D M Royal, R R Sharp  17074820  2006-11-01   13       NaN
# 2  M W Foster, C D M Royal, R R Sharp  17074820  2006-11-01   13       NaN
# ...

# %%
information_train.shape[0]
# Out:
# 3522

# %%
frames = [result,result_1]
combined_df = pd.concat(frames,ignore_index=True)
combined_df
# Out:
#                                             abstract  \
# 0  Among bioethicists and members of the public, ...
# 1  Among bioethicists and members of the public, ...
# 2  Among bioethicists and members of the public, ...
# 3  Among bioethicists and members of the public, ...
# 4  Among bioethicists and members of the public, ...
# 5  Genomics resources that use samples from ident...
# 6  Genomics resources that use samples from ident...
# 7  Genomics resources that use samples from ident...
# 8  Genomics resources that use samples from ident...
# 9  Genomics resources that use samples from ident...
#
#                                        article_title  \
# 0  The routinisation of genomics and genetics: im...
# 1  The routinisation of genomics and genetics: im...
# 2  The routinisation of genomics and genetics: im...
# 3  The routinisation of genomics and genetics: im...
# 4  The routinisation of genomics and genetics: im...
# 5  Integrating ethics and science in the Internat...
# ...

# %%
information_train.set.value_counts()
# Out:
# 16    753
# 3     603
# 5     502
# 14    410
# 8     388
# 18    368
# 13    218
# 2     173
# 6     107
# Name: set, dtype: int64

# %%
i = 0
for index, row in information_train.iterrows():
    print (index)
    print (type(row))
    i += 1
    if i ==3:
        break
# Out:
# 0
# <class 'pandas.core.series.Series'>
# 1
# <class 'pandas.core.series.Series'>
# 2
# <class 'pandas.core.series.Series'>

# %%
first_row_dataframe = information_train.drop(information_train.index[[0]])
information_train
# Out:
#                                                abstract  \
# 0     Among bioethicists and members of the public, ...
# 1     Genomics resources that use samples from ident...
# 2     Alleviating health disparities in the United S...
# 3     Protecting the confidentiality of genetic rese...
# 4     Whereas the human linkage map appears on limit...
# 5     We have examined differences in diversity at 6...
# 6     Because defects in the phenylalanine hydroxyla...
# 7     It is often taken for granted that the human s...
# 8     The practicality and moral value of community ...
# 9     One widely used measure of familial aggregatio...
# 10    AIM—To review the prevalence and causes of bli...
# 11    A debate has arisen regarding the validity of ...
# 12    Genetic epidemiology developed in the middle o...
# 13    The high frequency of single-nucleotide polymo...
# 14    Genetic discrimination refers to discriminatio...
# 15    Allelic association provides a means to map di...
# ...

# %%
set_14_train = information_train[information_train.set==14]

# %%
# pd.option_context('display.max_colwidth', 200)
for i in range(1,5):
    print (set_14_train.iloc[i]['article_title'])
# Out:
# The diploid genome sequence of an Asian individual
# Deletion polymorphism upstream of IRGM associated with altered IRGM expression and Crohn’s disease
# Ultrafast and memory-efficient alignment of short DNA sequences to the human genome
# TopHat: discovering splice junctions with RNA-Seq

# %%
information_train[information_train.set==6].count()
# Out:
# abstract         107
# article_title    107
# author_str       106
# pmid             107
# pub_date         107
# set              107
# full_Text         17
# dtype: int64

# %%
train.head()
# Out:
#                                        pmid,ref_list
# 0     17074820,"['15153999', '15213210', '7668302']"
# 1  15153999,"['12721363', '9096352', '10788337', ...
# 2                15213210,"['11466240', '12184798']"
# 3                                7668302,['1539589']
# 4  12721363,"['9465087', '11842208', '11309498', ...
